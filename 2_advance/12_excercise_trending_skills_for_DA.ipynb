# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast 
import numpy as np
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')

df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df['job_skills']  = df['job_skills'].apply(lambda x : ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_exploded = df.explode(['job_skills']).copy()

# %%
df_exploded.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 1          Data Analyst                                       Data Analyst
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 1               False                Mexico 2023-01-14 13:18:07
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
df_exploded_DA = df_exploded[df_exploded['job_title_short'] == 'Data Analyst'].copy()
df_exploded_DA.head(4)
# Out:
#   job_title_short     job_title                  job_location  \
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
#
#             job_via job_schedule_type  job_work_from_home search_location  \
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1 2023-01-14 13:18:07                  False                 False
# 1 2023-01-14 13:18:07                  False                 False
# 1 2023-01-14 13:18:07                  False                 False
# ...

# %%
df_exploded_DA['month'] = df_exploded_DA['job_posted_date'].dt.strftime('%b')
df_exploded_DA['month_num'] = df_exploded_DA['job_posted_date'].dt.month
df_exploded_DA.sort_values(by='month_num',ascending= True, inplace=True)
df_exploded_DA.tail(6)
# Out:
#        job_title_short              job_title job_location  \
# 440398    Data Analyst           Data Analyst    Singapore
# 63448     Data Analyst           Data Analyst  Doha, Qatar
# 440421    Data Analyst        BI Data Analyst     Anywhere
# 778145    Data Analyst  Business Data Analyst    Singapore
# 440398    Data Analyst           Data Analyst    Singapore
# 468264    Data Analyst           Data Analyst    Singapore
#
#                        job_via job_schedule_type  job_work_from_home  \
# 440398     via BeBee Singapore         Full-time               False
# 63448       via BeBee دولة قطر         Full-time               False
# 440421            via LinkedIn         Full-time                True
# 778145  via Singapore | JobsDB         Full-time               False
# 440398     via BeBee Singapore         Full-time               False
# 468264     via BeBee Singapore         Full-time               False
#
# ...

# %%
#df_exploded_DA.value_counts('job_skills').sort_values(ascending=False).head(5)

# %%
df_pivot =df_exploded_DA.pivot_table( index= ['month_num','month'] , columns='job_skills', aggfunc= 'size', fill_value=0)

# %%
df_pivot_final=df_pivot.droplevel('month_num')

# %%
df_pivot_final
# Out:
# job_skills  airflow  airtable  alteryx  angular  angular.js  ansible  apl  \
# month
# Jan             197        17      551       63           2       20    2
# Feb             169         2      448       49           0       14    1
# Mar             181         4      442       34           0       23    6
# Apr             155         4      413       22           0       11    8
# May             128         8      310       30           0       19    9
# Jun             164        14      393       29           0       14    9
# Jul             207         4      366       15           0        8    5
# Aug             197         3      413       21           0       12   10
# Sep             118         4      317       21           0       14    3
# Oct             173        11      350       40           0       19    0
# Nov             169         7      293       24           0       19    0
# Dec             144        10      274       28           0       13    0
# ...

# %%
df_pivot_final.loc['total'] = df_pivot_final.sum()

# %%
df_pivot_final
# Out:
# job_skills  airflow  airtable  alteryx  angular  angular.js  ansible  apl  \
# month
# Jan             197        17      551       63           2       20    2
# Feb             169         2      448       49           0       14    1
# Mar             181         4      442       34           0       23    6
# Apr             155         4      413       22           0       11    8
# May             128         8      310       30           0       19    9
# Jun             164        14      393       29           0       14    9
# Jul             207         4      366       15           0        8    5
# Aug             197         3      413       21           0       12   10
# Sep             118         4      317       21           0       14    3
# Oct             173        11      350       40           0       19    0
# Nov             169         7      293       24           0       19    0
# Dec             144        10      274       28           0       13    0
# ...

# %%
df_pivot_final.loc['total'].sort_values(ascending=False).index
# Out:
# Index(['sql', 'excel', 'python', 'tableau', 'power bi', 'r', 'sas',
#        'powerpoint', 'word', 'sap',
#        ...
#        'angular.js', 'xamarin', 'gtx', 'nuxt.js', 'ovh', 'esquisse', 'suse',
#        'capacitor', 'chainer', 'msaccess'],
#       dtype='object', name='job_skills', length=235)

# %%
df_pivot_final =df_pivot_final[df_pivot_final.loc['total'].sort_values(ascending=False).index]
df_pivot_final
# Out:
# job_skills    sql  excel  python  tableau  power bi      r    sas  powerpoint  \
# month
# Jan         11336   8170    6606     5596      4285   3607   3830        1880
# Feb          7947   5772    4751     3936      3307   2576   2634        1291
# Mar          7868   5675    4741     4051      3176   2650   2554        1266
# Apr          7553   5496    4557     3776      3106   2399   2598        1190
# May          6617   4773    4070     3245      2695   2093   1940         979
# Jun          7584   5724    4707     3812      3275   2442   2174        1173
# Jul          7687   5513    4831     3928      3350   2444   2118        1096
# Aug          8823   6482    5576     4533      3859   2975   2560        1332
# Sep          6829   4886    4229     3446      3118   2146   1880         944
# Oct          7474   5217    4693     3709      3340   2380   2114         955
# Nov          6652   4776    4233     3284      3012   2159   1738         894
# ...

# %%
df_pivot_final = df_pivot_final.drop('total')

# %%
df_pivot_final
# Out:
# job_skills    sql  excel  python  tableau  power bi     r   sas  powerpoint  \
# month
# Jan         11336   8170    6606     5596      4285  3607  3830        1880
# Feb          7947   5772    4751     3936      3307  2576  2634        1291
# Mar          7868   5675    4741     4051      3176  2650  2554        1266
# Apr          7553   5496    4557     3776      3106  2399  2598        1190
# May          6617   4773    4070     3245      2695  2093  1940         979
# Jun          7584   5724    4707     3812      3275  2442  2174        1173
# Jul          7687   5513    4831     3928      3350  2444  2118        1096
# Aug          8823   6482    5576     4533      3859  2975  2560        1332
# Sep          6829   4886    4229     3446      3118  2146  1880         944
# Oct          7474   5217    4693     3709      3340  2380  2114         955
# Nov          6652   4776    4233     3284      3012  2159  1738         894
# ...

# %%
df_pivot_final = df_pivot_final.iloc[:,:6]
df_pivot_final.plot(kind='line')
plt.title('Top 5 Skills for Data Analyst Monthly')
plt.ylabel('count')
plt.xlabel('2023')
plt.show()
